# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./data/midwest.csv")

# %%
data
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 432  3048   WAUKESHA    WI  0.034    304715  8962.205880    298313      1096
# 433  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 434  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 435  3051  WINNEBAGO    WI  0.035    140320  4009.142860    136822       697
# 436  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
data = data.assign(poppercent = (data['poptotal'] - data['popadults']) / data['poptotal'])
data.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian  ...  percprof  poppovertyknown  percpovertyknown  \
# 0             98       249  ...  4.355859            63628         96.274777
# 1             19        48  ...  2.870315            10529         99.087145
# 2             35        16  ...  4.488572            14235         94.956974
# 3             46       150  ...  4.197800            30337         98.477569
# 4             14         5  ...  3.367680             4815         82.505140
#
# ...

# %%
data.sort_values('poppercent', ascending = False).head()
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 230  1233   ISABELLA    MI  0.034     54624  1606.588240     52212       635
# 404  3020  MENOMINEE    WI  0.021      3890   185.238095       416         0
# 281  2013     ATHENS    OH  0.030     59549  1984.966670     56163      1678
# 247  1250    MECOSTA    MI  0.034     37308  1097.294120     35739       978
# 154   715     MONROE    IN  0.024    108978  4540.750000    102752      2835
#
#      popamerindian  popasian  ...   percprof  poppovertyknown  \
# 230           1020       456  ...  10.003020            48498
# 404           3469         0  ...   0.520291             3820
# 281            167      1374  ...  12.044799            51002
# 247            258       187  ...   7.845304            32627
# 154            216      2713  ...  17.201227            93693
#
#      percpovertyknown  percbelowpoverty  percchildbelowpovert  \
# 230         88.785149         24.854633             21.269687
# ...

# %%
data = data.assign(classification = 
                   np.where(data['poppercent'] >= 0.4, 'large',
    np.where(data['poppercent']>= 0.3, 'middle', 'small')
))

# %%
data.value_counts('classification')
# Out:
# classification
# middle    396
# large      32
# small       9
# Name: count, dtype: int64

# %%
data.assign(asianpercent = data['popasian'] / data['poptotal']).sort_values('asianpercent')[['state', 'county', 'asianpercent']].head(10)
# Out:
#     state     county  asianpercent
# 404    WI  MENOMINEE      0.000000
# 105    IN     BENTON      0.000106
# 109    IN    CARROLL      0.000159
# 358    OH     VINTON      0.000270
# 390    WI       IRON      0.000325
# 85     IL      SCOTT      0.000532
# 112    IN       CLAY      0.000607
# 261    MI     OSCODA      0.000638
# 340    OH      PERRY      0.000665
# 73     IL      PIATT      0.000707

# %%
import seaborn as sns

# %%
sns.scatterplot(data = data, x = 'poptotal', y = 'popasian').set(xlim = (0, 500000), ylim = (0, 10000))
# Out:
# [(0.0, 500000.0), (0.0, 10000.0)]
