# %%
import pandas as pd
import numpy as np

# %%
mpg = pd.read_csv('./data/mpg.csv')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
mpg['total'] = (mpg['cty'] + mpg['hwy']) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
mpg['total'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg['total'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# <p> total 연비의 평균과 중앙값이 약 20이다</p>
# <p> total 연비가 20 ~ 22.5 사이인 자동차 모델이 많다.</p>
# <p>연비는 대부분 25 이하, 25를 넘기는 자동차 모델은 많지 않다.</p>
#
# <p>연비가 20이 넘는 자동차에 고연비 합격 판정을 내리면 될듯하다.</p>

# %%
mpg['test'] = np.where(mpg['total'] >= 20, "pass", "fail")
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test
# 0   23.5  pass
# 1   25.0  pass
# 2   25.5  pass
# 3   25.5  pass
# 4   21.0  pass

# %%
count_test = mpg['test'].value_counts()

# %%
count_test.plot.bar(rot = 0)
# Out:
# <Axes: xlabel='test'>

# %%
mpg['Grade'] = np.where(mpg['total'] >= 30, 'A',
                       np.where(mpg['total'] >= 20, 'B', 'C'))

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test Grade
# 0   23.5  pass     B
# 1   25.0  pass     B
# 2   25.5  pass     B
# 3   25.5  pass     B
# 4   21.0  pass     B

# %%
count_grade = mpg['Grade'].value_counts().sort_index()
count_grade
# Out:
# Grade
# A     10
# B    118
# C    106
# Name: count, dtype: int64

# %%
count_grade.plot.bar(rot = 0)
# Out:
# <Axes: xlabel='Grade'>

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  total  test Grade
# 0    compact   23.5  pass     B
# 1    compact   25.0  pass     B
# 2    compact   25.5  pass     B
# 3    compact   25.5  pass     B
# 4    compact   21.0  pass     B
# ..       ...    ...   ...   ...
# 229  midsize   23.5  pass     B
# 230  midsize   25.0  pass     B
# 231  midsize   21.0  pass     B
# 232  midsize   22.0  pass     B
# 233  midsize   21.5  pass     B
#
# [234 rows x 14 columns]

# %%
df = mpg[['category', 'cty']]

# %%
suv_cty = df.query('category == "suv"')['cty'].mean()
compact_cty = df.query('category == "compact"')['cty'].mean()

# %%
mpg_audi = mpg.query('manufacturer == "audi"')

# %%
mpg_audi
# Out:
#    manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0          audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1          audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2          audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3          audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4          audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5          audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6          audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7          audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 8          audi  a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 9          audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 10         audi  a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# 11         audi  a4 quattro    2.8  1999    6    auto(l5)   4   15   25  p
# 12         audi  a4 quattro    2.8  1999    6  manual(m5)   4   17   25  p
# 13         audi  a4 quattro    3.1  2008    6    auto(s6)   4   17   25  p
# 14         audi  a4 quattro    3.1  2008    6  manual(m6)   4   15   25  p
# 15         audi  a6 quattro    2.8  1999    6    auto(l5)   4   15   24  p
# 16         audi  a6 quattro    3.1  2008    6    auto(s6)   4   17   25  p
# 17         audi  a6 quattro    4.2  2008    8    auto(s6)   4   16   23  p
#
#    category  total  test Grade
# 0   compact   23.5  pass     B
# 1   compact   25.0  pass     B
# 2   compact   25.5  pass     B
# 3   compact   25.5  pass     B
# 4   compact   21.0  pass     B
# 5   compact   22.0  pass     B
# 6   compact   22.5  pass     B
# 7   compact   22.0  pass     B
# 8   compact   20.5  pass     B
# 9   compact   24.0  pass     B
# 10  compact   23.0  pass     B
# 11  compact   20.0  pass     B
# 12  compact   21.0  pass     B
# 13  compact   21.0  pass     B
# 14  compact   20.0  pass     B
# 15  midsize   19.5  fail     C
# 16  midsize   21.0  pass     B
# 17  midsize   19.5  fail     C

# %%
mpg_audi.sort_values('hwy', ascending = False).head()
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#   category  total  test Grade
# 2  compact   25.5  pass     B
# 3  compact   25.5  pass     B
# 0  compact   23.5  pass     B
# 1  compact   25.0  pass     B
# 9  compact   24.0  pass     B

# %%
total_mpg = mpg.copy().assign(total = mpg['cty'] + mpg['hwy'],
                             mean = lambda x : (x['total'] / 2)).sort_values('mean', ascending = False).head(3)

# %%
total_mpg
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category  total  test Grade  mean
# 221  subcompact     79  pass     A  39.5
# 212     compact     77  pass     A  38.5
# 222  subcompact     70  pass     A  35.0

# %%
mpg.groupby(['manufacturer', 'drv']).agg(mean_cty = ('cty', 'mean'))
# Out:
#                    mean_cty
# manufacturer drv
# audi         4    16.818182
#              f    18.857143
# chevrolet    4    12.500000
#              f    18.800000
#              r    14.100000
# dodge        4    12.000000
#              f    15.818182
# ford         4    13.307692
#              r    14.750000
# honda        f    24.444444
# hyundai      f    18.642857
# jeep         4    13.500000
# land rover   4    11.500000
# lincoln      r    11.333333
# mercury      4    13.250000
# nissan       4    13.750000
#              f    20.000000
# pontiac      f    17.000000
# subaru       4    19.285714
# toyota       4    14.933333
#              f    21.368421
# volkswagen   f    20.925926

# %%
mpg.query('manufacturer == "audi"').groupby('drv').agg(n = ('cty', 'count'))
# Out:
#       n
# drv
# 4    11
# f     7

# %%
mpg[mpg['manufacturer'] == 'audi']['drv'].value_counts()
# Out:
# drv
# 4    11
# f     7
# Name: count, dtype: int64

# %%
mpg['category'].value_counts()
# Out:
# category
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: count, dtype: int64

# %%
mpg.query('category == "suv"')\
    .assign(total = lambda x : x['cty'] + x['hwy'])\
    .groupby('manufacturer')\
    .agg(mean = ('total', 'mean'))\
    .sort_values('mean', ascending = False)\
    .head()
# Out:
#                    mean
# manufacturer
# subaru        43.833333
# toyota        32.625000
# nissan        31.750000
# mercury       31.250000
# jeep          31.125000

# %%
mpg.groupby('category').agg(mean_cty = ('cty', 'mean')).sort_values('mean_cty', ascending = False)
# Out:
#              mean_cty
# category
# subcompact  20.371429
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# 2seater     15.400000
# suv         13.500000
# pickup      13.000000

# %%
mpg.groupby('manufacturer').agg(mean_hwy = ('hwy', 'mean')).sort_values('mean_hwy', ascending = False).head(3)
# Out:
#                mean_hwy
# manufacturer
# honda         32.555556
# volkswagen    29.222222
# hyundai       26.857143

# %%
mpg.query('category == "compact"').groupby('manufacturer').agg(n = ('manufacturer', 'count')).sort_values('n', ascending = False)
# Out:
#                n
# manufacturer
# audi          15
# volkswagen    14
# toyota        12
# subaru         4
# nissan         2

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  total  test Grade
# 0    compact   23.5  pass     B
# 1    compact   25.0  pass     B
# 2    compact   25.5  pass     B
# 3    compact   25.5  pass     B
# 4    compact   21.0  pass     B
# ..       ...    ...   ...   ...
# 229  midsize   23.5  pass     B
# 230  midsize   25.0  pass     B
# 231  midsize   21.0  pass     B
# 232  midsize   22.0  pass     B
# 233  midsize   21.5  pass     B
#
# [234 rows x 14 columns]

# %%
fuel = pd.DataFrame(
    {'f1' : ['c', 'd', 'e', 'p', 'r'],
     'price_f1' : [2.35, 2.38, 2.11, 2.76, 2.22]}
)
fuel
# Out:
#   f1  price_f1
# 0  c      2.35
# 1  d      2.38
# 2  e      2.11
# 3  p      2.76
# 4  r      2.22

# %%
pd.merge(mpg, fuel)
